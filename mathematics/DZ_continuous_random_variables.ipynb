# %% [markdown]
#     Задание 1:
#
# Получить интуицию, на что влияют параметры распределений. Построить по 5 функций плотностей с разными параметрами для каждого распределения: нормальное, экспоненциальное, Стьюдента на одном графике.

# %%
import numpy as np

# %%
from scipy.stats import norm

import matplotlib.pyplot as plt

# %%
x = np.linspace(norm.ppf(0.01),norm.ppf(0.99), 100)
fig, ax = plt.subplots(1, 1)
ax.plot(x, norm.pdf(x),'r-', lw=5, alpha=0.6, label='norm pdf')
plt.show()

# %%
for vals in [(4.0, 1.5), (1.5, 0.5), (5.5, 0.5), (3.0, 0.75), (2.0, 0.9)]:
    norm_rv = norm(loc=vals[0], scale=vals[1])
    x = np.linspace(0, 7, 100)
    y = norm_rv.pdf(x)
    plt.plot(x, y)
    plt.show()

# %%
x = np.linspace(norm.ppf(0.01),norm.ppf(0.99), 100)
fig, ax = plt.subplots(1, 1)
ax.plot(x, norm.pdf(x),'r-', lw=5, alpha=0.6, label='norm pdf')
plt.show()

# %%
from scipy.stats import expon

# %%
for values in [(0.02, 1.5), (0.02, 6), (0.9, 3), (1.0, 0.75), (3.0, 5)]:
    expon_rv = expon(loc=values[0], scale=values[1])
    x = np.linspace(0, 6, 100)
    y = expon_rv.pdf(x)
    plt.plot(x, y)
    plt.show()

# %%
x = np.linspace(expon.ppf(0.01),

                expon.ppf(0.99), 100)
fig, ax = plt.subplots(1, 1)
ax.plot(x, expon.pdf(x),

       'r-', lw=5, alpha=0.6, label='expon pdf')
plt.show()

# %%
from scipy.stats import t

# %%
df = 2.74
for value in [(0.01, 0.99), (0.02, 0.88), (0.05, 0.55), (0.5, 0.99), (0.01, 0.5)]:
    x = np.linspace(t.ppf(value[0], df), t.ppf(value[1], df), 100)
    fig, ax = plt.subplots(1, 1)
    ax.plot(x, t.pdf(x, df),  'g-', lw=5, alpha=0.6, label='t pdf')

# %%
x = np.linspace(t.ppf(0.01, df),

                t.ppf(0.99, df), 100)
fig, ax = plt.subplots(1, 1)

ax.plot(x, t.pdf(x, df),

       'r-', lw=5, alpha=0.6, label='t pdf')
plt.show()

# %% [markdown]
#     Задание 2
#
# Непрерывная случайная величина задана плотностью распределения:$$ f(\xi) = C, \xi \in [0;5];f(\xi) = 0, \xi \notin [0;5]$$Найдите C, математическое ожидание $\xi$ а также вероятность попадания в отрезок $[3.5;7]$, т.е. P(3.5 < $\xi$ < 7).

# %% [markdown]
#     Задание 3
#
# Известно, что светофор горит 54 секунды красным, 4 секунды жёлтым и 28 секунд зелёным. Посчитайте, какое количество информации несёт сообщение о цвете светофора в текущий момент. А что будет в случае 28, 28 и 28 секунд для каждого цвета?

# %%
import math

# %%
a = 54 + 4 + 28
a
# Out:
# 86

# %%
red = 54/86
yellow = 4/86
green = 28/86

# %%
inform = -(red*math.log2(red) + yellow*math.log2(yellow) + green*math.log2(green)) #ФОРМУЛА ШЕННОНА ДЛЯ ПОДСЧЕТА ИНФОРМАЦИИ
inform
# Out:
# 1.154522162441165
